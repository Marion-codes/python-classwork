# %%
"""
Project Name: Functions
Created By: Marion Brown
Date: 6/30/26
Description: Volt Knight
"""

def volt_knight():
  # Asking the user to give an input for the knights name, ability and weakness
  name = input("Enter Volt Knight's name: ")
  ability = input("Enter Volt Knight's Ability: ")
  weakness = input("Enter Volt Knight's Weakness: ")

  #Printing Volt Knights name, ability and weakness
  print(f"\nVolt Knight: {name}")
  print(f"Special Ability: {ability}")
  print(f"Weakness: {weakness}")

# Calling the function to run this program
volt_knight()
# Out:
# Enter Volt Knight's name: Marion Brown
# Enter Volt Knight's Ability: Invisibility
# Enter Volt Knight's Weakness: Water
#
# Volt Knight: Marion Brown
# Special Ability: Invisibility
# Weakness: Water
