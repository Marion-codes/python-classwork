# %%
""""
Project: Categorizing Inputs Assignment
Name: Marion Brown
Date: 6/19/26
Description: I am grabbing the users inputs and putting it into a table to display if the status of the item is low, fair, or full.
"""
name1 = input("Enter the name of item 1: ") # Grabs the users name of input 1
type1 = input("What type of item is this?: ") # Inputs the type of item that you put
item1 = int(input("How much of this item do you have?: ")) # Inputs how much of this item you have

if item1 < 100: # If item 1 is lower then 100, it will print out low (for status1)
  status1 = "Low"
elif item1 <= 200: # If item 1 is less than or equal to 200, it will print out fair (for status1)
  status1 = "Fair"
else:
  status1 = "Full" # If item 1 has more than 200, it will print out full

name2 = input("Enter the name of item 2: ") # Grabs the users name of input 2
type2 = input("What type of item is this?: ")  # Inputs the type of item that you put
item2 = int(input("How much of this item do you have?: ")) # Inputs how much of this item you have

if item2 < 100: # If item 2 is lower then 100, it will print out low (for status2)
  status2 = "Low"
elif item2 <= 200: # If item 2 is less than or equal to 200, it will print out fair (for status2)
  status2 = "Fair"
else:
  status2 = "Full" # If item 2 has more than 200, it will print out full

name3 = input("Enter the name of item 3: ") # Grabs the users name of input 3
type3 = input("What type of item is this?: ")  # Inputs the type of item that you put
item3 = int(input("How much of this item do you have?: ")) # Inputs how much of this item you have

if item3 < 100: # If item 3 is lower then 100, it will print out low (for status3)
  status3 = "Low"
elif item3 <= 200: # If item 3 is less than or equal to 200, it will print out fair (for status3)
  status3 = "Fair"
else:
  status3 = "Full" # If item 3 has more than 200, it will print out full

name4 = input("Enter the name of item 4: ") # Grabs the users name of input 4
type4 = input("What type of item is this?: ")  # Inputs the type of item that you put
item4 = int(input("How much of this item do you have?: ")) # Inputs how much of this item you have

if item4 < 100: # If item 4 is lower then 100, it will print out low (for status4)
  status4 = "Low"
elif item4 <= 200: # If item 4 is less than or equal to 200, it will print out fair (for status4)
  status4 = "Fair"
else:
  status4 = "Full" # If item 4 has more than 200, it will print out full

print(f"{'Item Name':<15}{'Item Type':<15}{'Amount':<15}{'Status':<15}")
print(f"{name1:<15}{type1:<15}{item1:<15}{status1:<15}")
print(f"{name2:<15}{type2:<15}{item2:<15}{status2:<15}")
print(f"{name3:<15}{type3:<15}{item3:<15}{status3:<15}")
print(f"{name4:15}{type4:<15}{item4:<15}{status4:<15}")
# Out:
# Enter the name of item 1: Pizza
# What type of item is this?: Food
# How much of this item do you have?: 102
# Enter the name of item 2: Grapes
# What type of item is this?: FOod
# How much of this item do you have?: 40
# Enter the name of item 3: Water bottles
# What type of item is this?: Drink
# How much of this item do you have?: 202
# Enter the name of item 4: Strawberries
# What type of item is this?: Food
# How much of this item do you have?: 150
# Item Name      Item Type      Amount         Status
# Pizza          Food           102            Fair
# Grapes         FOod           40             Low
# Water bottles  Drink          202            Full
# Strawberries   Food           150            Fair
