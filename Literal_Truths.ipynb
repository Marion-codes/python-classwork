# %%
print("Marion is the fastest typer in the world.") # This is printing my statement that is in the quotation marks "", whcih is called a string literal.
# Out:
# Marion is the fastest typer in the world.

# %%
print(36) # This is a integer literal that prints out my current age x2.
# Out:
# 36

# %%
print(True) # This prints out a boolean literal that is "True".
# Out:
# True

# %%
print(21.8) # This shows a decimal number using a float literal.
# Out:
# 21.8

# %%
print(None) # Prints out the void
# Out:
# None
