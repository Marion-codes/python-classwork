# %%
name = input("What is your name? ") # Inputs users name
age = int(input("How old are you? ")) # Inputs users age
favorite_food = input("What is your favorite food? ") # Inputs users favorite food
number = int(input("What is your favorite number? ")) # Inputs users favorite number
state = input("What state are you from? ") # Inputs users state

print("Hello", name,) # Prints users name
print("You are", age,"years old") # Prints users age
print("Your favorite food is", favorite_food,) # Prints users favorite food
print("Your favorite number is", number,) # Prints users favorite nuber
print("You are from", state,) # Prints users state

print("Thank you for playing my input minigame!") # Prints a thank you message for playing the minigame
# Out:
# What is your name? Marion
# How old are you? 18
# What is your favorite food? pizza
# What is your favorite number? 11
# What state are you from? mississippi
# Hello Marion
# You are 18 years old
# Your favorite food is pizza
# Your favorite number is 11
# You are from mississippi
# Thank you for playing my input minigame!
