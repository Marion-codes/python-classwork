# %%
name1 = input("Name: ")
category1 = input("Category: ")
year1 = input("Year: ")
achieve1 = input("Achievement: ")

name2 = input("Name: ")
category2 = input("Category: ")
year2 = input("Year: ")
achieve2 = input("Achievement: ")


name3 = input("Name: ")
category3 = input("Category: ")
year3 = input("Year: ")
achieve3 = input("Achievement: ")


name4 = input("Name: ")
category4 = input("Category: ")
year4 = input("Year: ")
achieve4 = input("Achievement: ")

table = """
|Name       | Category       | Year     | Achievement     |
|-----------|----------------|----------|-----------------|
| {:<10} | {:<10} | {:<6} | {:<12} |
| {:<10} | {:<10} | {:<6} | {:<12} |
| {:<10} | {:<10} | {:<6} | {:<12} |
| {:<10} | {:<10} | {:<6} | {:<12} |
""".format(
name1,category1,year1,achieve1,
name2,category2,year2,achieve2,
name3,category3,year3,achieve3,
name4,category4,year4,achieve4)

print(table)=
# Out:
# Name: Zelda
# Category: RPG
# Year: 1986
# Achievement: Triforce
# Name: PacMan
# Category: Arcade
# Year: 1980
# Achievement: Highscore
# Name: Tetros
# Category: Puzzle
# Year: 1984
# Achievement: MaxLines
# Name: Halo
# Category: Shooter
# Year: 2001
# Achievement: King
#
# |Name       | Category       | Year     | Achievement     |
# |-----------|----------------|----------|-----------------|
# | Zelda      | RPG        | 1986   | Triforce     |
# | PacMan     | Arcade     | 1980   | Highscore    |
# | Tetros     | Puzzle     | 1984   | MaxLines     |
# | Halo       | Shooter    | 2001   | King         |
