# %%
print("Hello, Earth! Marion is here to take over the coding world!")

print("Everyone will look up to me as Sir Marion!")
# Out:
# Hello, Earth! Marion is here to take over the coding world!
# Everyone will look up to me as Sir Marion!
