# %%
name = input("What is your name? ")
age = int(input("How old are you? "))
city = input("What city are you from? ")

print("My name is %s, I am %d years old, and I live in %s." % (name, age, city))
print("My name is {}, I am {} years old, and I live in {}.".format(name, age, city))
print(f"My name is {name}, I am {age} years old, and I live in {city}.")
# Out:
# What is your name? Marion
# How old are you? 18
# What city are you from? Hattiesburg
# My name is Marion, I am 18 years old, and I live in Hattiesburg.
# My name is Marion, I am 18 years old, and I live in Hattiesburg.
# My name is Marion, I am 18 years old, and I live in Hattiesburg.
