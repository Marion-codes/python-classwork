# %%
"""
Project: The Legend of Python
Name: Marion Brown
Date: 6/17/26
Description: Find a way to open the gate and grab the treasure.
"""
print("Welcome to The Legend of Python!") # Title
player_name = input("Enter your name, adventurer: ") # Input of users name to the game

print("Do you choose (1) Chocolate or (2) Strawberry?") # The biome the user has to choose
choice1 = input("Enter 1 or 2: ")

if choice1 == "1":
  print("You may enter the Chocolate biome.")
else:
  print("You may enter the Strawberry biome.")

print("You encountered a giant locked gate. Do you (1) Climb over the rocks to get over the gate or (2) Break through the gate using the hammer.")
choice2 = input("Enter (1) or (2): ")

if choice2 == "1":
  print("The rocks was not high enough to get over the gate.")

  item = input("Do you want to use a balloon to fly over the gate instead? (yes or no): ")
  if item == "yes":
    print("The balloon flew you just over the gate.")
    print(f"Congratulations, {player_name}!, You found the treasure behind the gate!")
  else:
    print("Without using a balloon, you can't get over the gate.")

elif choice2 == "2":
  print("You try to use the hammer to break through the gate, but the gate does not move at all.")
  print("The hammer was not strong enough to break through the gate.")

else:
  print("You became tired, and went to sleep in front of the gate.")
# Out:
# Welcome to The Legend of Python!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_33649/2034358582.py in <cell line: 0>()
#       6 """
#       7 print("Welcome to The Legend of Python!") # Title
# ----> 8 player_name = input("Enter your name, adventurer: ") # Input of users name to the game
#       9
#      10 print("Do you choose (1) Chocolate or (2) Strawberry?") # The biome the user has to choose
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...
