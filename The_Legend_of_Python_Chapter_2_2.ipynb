# %%
print("Sir Marion") # String
# Out:
# Sir Marion

# %%
print(18) # Integer
# Out:
# 18

# %%
print(3.19) # Float
# Out:
# 3.19

# %%
print(False) # Boolean
# Out:
# False

# %%
print(None) # None
# Out:
# None

# %% [markdown]
# String represents text inside of quotation marks. Integer shows a whole number. Float is a number that has a decimal value. Boolean is a value that is either True or False. None is no value.
